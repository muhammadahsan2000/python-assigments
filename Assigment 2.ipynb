# %%
# Initialize an empty list to store items
grocery_list = []

# %%
# Ask the user for the number of items
num_items = int(input("Enter the number of items in your shopping list: "))

# Use a for loop to iteratively ask the user for each item
for i in range(num_items):
    item = input(f"Enter item #{i + 1}: ")
    grocery_list.append(item)

while True:
    print("\nMenu:")
    print("1. Display current list")
    print("2. Delete item from the list")
    print("3. Update item in the list")
    print("4. Add item to the list")
    print("5. Show entire shopping list")
    print("6. Exit")

    choice = input("Enter your choice (1-6): ")

    if choice == '1':
        if not grocery_list:
            print("Your shopping list is empty.")
        else:
            print("Your current shopping list:")
            for index, item in enumerate(grocery_list, start=1):
                print(f"{index}. {item}")
    elif choice == '2':
        if not grocery_list:
            print("Your shopping list is empty.")
        else:
            print("Your current shopping list:")
            for index, item in enumerate(grocery_list, start=1):
                print(f"{index}. {item}")
            
            item_to_delete = int(input("Enter the number of the item to delete: "))
            if 1 <= item_to_delete <= len(grocery_list):
                deleted_item = grocery_list.pop(item_to_delete - 1)
                print(f"{deleted_item} deleted from the list.")
            else:
                print("Invalid item number.")
    elif choice == '3':
        if not grocery_list:
            print("Your shopping list is empty.")
        else:
            print("Your current shopping list:")
            for index, item in enumerate(grocery_list, start=1):
                print(f"{index}. {item}")
            
            item_to_update = int(input("Enter the number of the item to update: "))
            if 1 <= item_to_update <= len(grocery_list):
                new_item = input("Enter the updated item: ")
                grocery_list[item_to_update - 1] = new_item
                print(f"Item updated: {grocery_list[item_to_update - 1]}")
            else:
                print("Invalid item number.")
    elif choice == '4':
        new_item = input("Enter the item to add: ")
        grocery_list.append(new_item)
        print(f"{new_item} added to the list.")
    elif choice == '5':
        print("Your entire shopping list:")
        for index, item in enumerate(grocery_list, start=1):
            print(f"{index}. {item}")
    elif choice == '6':
        print("Exiting the program. Goodbye!")
        break
    else:
        print("Invalid choice. Please enter a number between 1 and 6.")
# Out:
# Enter the number of items in your shopping list: 4
# Enter item #1: dff
# Enter item #2: ff
# Enter item #3: ff
# Enter item #4: ff
#
# Menu:
# 1. Display current list
# 2. Delete item from the list
# 3. Update item in the list
# 4. Add item to the list
# 5. Show entire shopping list
# 6. Exit
# Enter your choice (1-6): 6
# Exiting the program. Goodbye!

# %% [markdown]
# # Scenario 2: Student Grades
# You are managing student grades using a dictionary. You need to calculate the average grade.take
# atleast 5 Students grades & then calculate the average.

# %%
# Initialize an empty dictionary to store student grades
student_grades = {}

# Get grades for at least 5 students
for _ in range(5):
    student_name = input("Enter student name: ")
    
    # Ensure that the entered grade is a valid float
    while True:
        try:
            grade = float(input(f"Enter {student_name}'s grade: "))
            break
        except ValueError:
            print("Invalid input. Please enter a valid grade.")

    student_grades[student_name] = grade

# Calculate the average grade
total_grades = sum(student_grades.values())
average_grade = total_grades / len(student_grades)

# Display the student grades and average
print("\nStudent Grades:")
for student, grade in student_grades.items():
    print(f"{student}: {grade}")

print("\nAverage Grade:", average_grade)
# Out:
# Enter student name: ahsan
# Enter ahsan's grade: A
# Invalid input. Please enter a valid grade.
# Enter ahsan's grade: 80
# Enter student name: qasim
# Enter qasim's grade: 90
# Enter student name: ahmed
# Enter ahmed's grade: 95
# Enter student name: huzaifa
# Enter huzaifa's grade: 60
# Enter student name: hamza
# Enter hamza's grade: 70
#
# Student Grades:
# ahsan: 80.0
# qasim: 90.0
# ahmed: 95.0
# huzaifa: 60.0
# hamza: 70.0
#
# Average Grade: 79.0

# %%
##scenario 2 question with type 
def calculate_average_grade(marks):
    total_marks = sum(marks)
    average_grade = total_marks / len(marks)
    return average_grade

students = []

num_students = int(input("Enter the number of students: "))

for i in range(num_students):
    student_type = input(f"Enter the type of student #{i + 1} (college/school/university): ").lower()
    
    if student_type == 'college':
        subject_marks = []
        for j in range(5):
            subject_marks.append(float(input(f"Enter marks for Subject {j + 1}: ")))
        
        average_grade = calculate_average_grade(subject_marks)
        students.append({'type': student_type, 'average_grade': average_grade})
    
    elif student_type == 'school':
        percentage = float(input("Enter the percentage: "))
        students.append({'type': student_type, 'percentage': percentage})
    
    elif student_type == 'university':
        cgpa = float(input("Enter the CGPA: "))
        students.append({'type': student_type, 'cgpa': cgpa})

# Calculate the overall average grade
total_average = 0
for student in students:
    if student['type'] == 'college':
        total_average += student['average_grade']
    elif student['type'] == 'school':
        total_average += student['percentage']
    elif student['type'] == 'university':
        total_average += student['cgpa']

overall_average = total_average / num_students

print(f"\nOverall Average Grade: {overall_average}")
# Out:
# Enter the number of students: 5
# Enter the type of student #1 (college/school/university): college
# Enter marks for Subject 1: 30
# Enter marks for Subject 2: 45
# Enter marks for Subject 3: 78
# Enter marks for Subject 4: 90
# Enter marks for Subject 5: 87
# Enter the type of student #2 (college/school/university): college
# Enter marks for Subject 1: 56
# Enter marks for Subject 2: 87
# Enter marks for Subject 3: 98
# Enter marks for Subject 4: 87
# Enter marks for Subject 5: 65
# Enter the type of student #3 (college/school/university): college
# Enter marks for Subject 1: 34
# Enter marks for Subject 2: 65
# Enter marks for Subject 3: 76
# Enter marks for Subject 4: 65
# Enter marks for Subject 5: 54
# Enter the type of student #4 (college/school/university): 43
# Enter the type of student #5 (college/school/university): college
# Enter marks for Subject 1: 45
# Enter marks for Subject 2: 87
# Enter marks for Subject 3: 87
# Enter marks for Subject 4: 98
# ...

# %% [markdown]
# # Scenario 3: Word Frequency Counter
# You are given a list of words, and you need to count the frequency of each word.
# word_list = ["apple", "banana", "apple", "orange", "banana", "grape", "apple"]

# %%
# Given list of words
word_list = ["apple", "banana", "apple", "orange", "banana", "grape", "apple"]

# Initialize an empty dictionary to store word frequencies
word_frequencies = {}


for word in word_list:
    if word in word_frequencies:
        word_frequencies[word] += 1
    else:
        word_frequencies[word] = 1

# Display the word frequencies
print("Word Frequencies:")
for word, frequency in word_frequencies.items():
    print(f"{word}: {frequency}")
# Out:
# Word Frequencies:
# apple: 3
# banana: 2
# orange: 1
# grape: 1

# %% [markdown]
# # Scenario 4: Password Strength Checker
# You are creating a program to check the strength of passwords based on certain criteria.
# • Password should be at least 8 characters long.
# • Password should contain at least one digit.
# • Password should contain at least one letter.

# %%
# Get user input for the password
password = input("Enter your password: ")

# Check the length of the password
if len(password) < 8:
    print("Password should be at least 8 characters long.")
else:
    # Check if the password contains at least one digit
    has_digit = any(char.isdigit() for char in password)
    
    # Check if the password contains at least one letter
    has_letter = any(char.isalpha() for char in password)

    # Check the criteria and provide feedback
    if not has_digit:
        print("Password should contain at least one digit.")
    elif not has_letter:
        print("Password should contain at least one letter.")
    else:
        print("Password is strong. Good job!")
# Out:
# Enter your password: ahsan
# Password should be at least 8 characters long.

# %% [markdown]
# # ##Scenario 05: Voting System (Annual Employee Recognition Awards)
# You are developing a simple voting system for a contest. Users can vote for their Favorite option, and
# you need to count the votes.
# In a corporate setting, the HR department is organizing the Annual Employee Recognition Awards,
# where employees get the opportunity to vote for their colleagues nominated in different categories.
# The HR team has decided to use a simple voting system to collect and tally votes for the nominees in
# various award categories. The script provided will be utilized for this purpose.
# Candidates: The nominees for different award categories, such as "Employee of the Year," "Team
# Player of the Year," and "Innovation Award," are represented by the list of candidates: 'Candidate A,'
# 'Candidate B,' and 'Candidate C.'
# Voting Process: Employees are requested to input the number of voters participating in the awards.
# Each voter is presented with a list of nominees, and they can vote for their preferred candidate by
# entering the corresponding number.
# Validation: The script ensures that the entered vote is within the valid range of candidates. If an
# employee enters an invalid vote, the system prompts them to choose a valid candidate.
# Recording Votes: The script records each vote for the selected candidate and prints a confirmation
# message indicating that the vote has been recorded.
# Results Display: Once all votes are collected, the system displays the voting results, showing the
# number of votes each candidate received in each category.
# Award Winners: Based on the voting results, the HR department can identify the winners for each
# award category and proceed with recognizing and rewarding the selected employees during the
# Annual Employee Recognition Ceremony.
# This script provides a straightforward and transparent way for employees to participate in the
# recognition process, fostering a sense of engagement and community within the organization. The
# HR team can use the collected votes to acknowledge and appreciate the efforts of outstanding
# employees in various aspects of their work.

# %%
# List of candidates
candidates = ['Candidate A', 'Candidate B', 'Candidate C']

# Initialize votes for each candidate
votes = {candidate: 0 for candidate in candidates}

# Get the number of voters
num_voters = int(input("Enter the number of voters participating: "))

# Voting process
for voter in range(1, num_voters + 1):
    print(f"\nVoter {voter}:")

    # Display candidates
    print("Candidates:")
    for i in range(len(candidates)):
        print(f"{i + 1}. {candidates[i]}")

    # Get and validate vote
    while True:
        try:
            vote = int(input("Enter the number corresponding to your preferred candidate: "))
            if 1 <= vote <= len(candidates):
                break
            else:
                print("Invalid vote. Please choose a valid candidate.")
        except ValueError:
            print("Invalid input. Please enter a number.")

    # Record the vote
    selected_candidate = candidates[vote - 1]
    votes[selected_candidate] += 1
    print(f"Vote recorded for {selected_candidate}.\n")

# Display the final results
print("\nVoting Results:")
for candidate, vote_count in votes.items():
    print(f"{candidate}: {vote_count} votes")
